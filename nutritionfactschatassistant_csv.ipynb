# %% [markdown]
# <a href="https://colab.research.google.com/github/milanimcgraw/Nutrition-Facts-Chat-Assistant/blob/main/nutritionfactschatassistant_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Nutrition Facts Chat Assistant (CSV csv content)**
#
# >The Nutrition Facts Chat Assistant is an advanced, AI-powered application that leverages Retrieval-Augmented Generation (RAG) to answer questions and provide accurate and contextual nutritional information. This project demonstrates the practical application of cutting-edge natural language processing techniques in the field of nutrition and dietary information. The USDA FoodData Central dataset was used for comprehensive nutritional information.

# %% [markdown]
# ## Install dependencies

# %%
# !pip install pandas numpy sentence-transformers faiss-cpu openai scikit-learn requests plotly ipywidgets streamlit
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.8.0.post1)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.51.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.10/dist-packages (1.39.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.1+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.6.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.9)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.8.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<6,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (71.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)

# %% [markdown]
# ## Load libraries and setup

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
import openai
from sklearn.metrics.pairwise import cosine_similarity
import ipywidgets as widgets
from IPython.display import display, clear_output
import os
import requests
from io import StringIO
import plotly.express as px
from datetime import datetime

# Load the OpenAI API key from the environment variables
openai.api_key = os.environ.get('OPENAI_API_KEY')

# %% [markdown]
# #Data Ingestion

# %%
# Base URL for the GitHub repository where CSV files are hosted
base_url = 'https://raw.githubusercontent.com/milanimcgraw/Nutrition-Facts-Chat-Assistant/main/FoodData_Central_foundation_food_csv_2024-04-18'

# List of all CSV file names in the GitHub folder
csv_files = [
    'acquisition_samples.csv',
    'agricultural_samples.csv',
    'food_attribute_type.csv',
    'food_attribute.csv',
    'food_calorie_conversion_factor.csv',
    'food_category.csv',
    'food_component.csv',
    'food_nutrient_conversion_factor.csv',
    'food_nutrient.csv',
    'food_portion.csv',
    'food_protein_conversion_factor.csv',
    'food_update_log_entry.csv',
    'food.csv',
    'foundation_food.csv',
    'input_food.csv',
    'lab_method_code.csv',
    'lab_method_nutrient.csv',
    'lab_method.csv',
    'market_acquisition.csv',
    'measure_unit.csv',
    'nutrient.csv',
    'sample_food.csv',
    'sub_sample_food.csv',
    'sub_sample_result.csv'
]

# Initialize a dictionary to hold DataFrames
dataframes = {}

# Load each CSV file into a DataFrame
for file in csv_files:
    file_url = f"{base_url}/{file}"  # Use the raw content URL
    response = requests.get(file_url)
    if response.status_code == 200:
        csv_content = StringIO(response.text)
        # Load CSV data into DataFrame
        df = pd.read_csv(csv_content)
        # Add a 'source_file' column to keep track of the source file
        df['source_file'] = file
        dataframes[file] = df
    else:
        print(f"Failed to fetch {file_url}")

# Now you can check the columns of each DataFrame
for file_name, df in dataframes.items():
    print(f"Columns in {file_name}: {df.columns.tolist()}")

# Example of filling missing values and creating a combined text column
combined_df = pd.DataFrame()  # Initialize an empty DataFrame

for file_name, df in dataframes.items():
    df.fillna('Unknown', inplace=True)  # Fill missing values

    # Example of constructing a 'text' column dynamically
    df['text'] = df.apply(lambda row: ' '.join([
        f"{col}: {row[col]}" for col in df.columns if pd.notna(row[col])
    ]), axis=1)

    # Concatenate DataFrames
    combined_df = pd.concat([combined_df, df], ignore_index=True)

# Save the preprocessed data
combined_df.to_csv("preprocessed_nutrition_data.csv", index=False)

print("Combined DataFrame shape:", combined_df.shape)
print("Sample data from combined DataFrame:")
print(combined_df.head())
# Out:
# <ipython-input-31-8035e0c61c70>:42: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_content)
# Columns in acquisition_samples.csv: ['fdc_id_of_sample_food', 'fdc_id_of_acquisition_food', 'source_file']
# Columns in agricultural_samples.csv: ['fdc_id', 'acquisition_date', 'market_class', 'treatment', 'state', 'source_file']
# Columns in food_attribute_type.csv: ['id', 'name', 'description', 'source_file']
# Columns in food_attribute.csv: ['id', 'fdc_id', 'seq_num', 'food_attribute_type_id', 'name', 'value', 'source_file']
# Columns in food_calorie_conversion_factor.csv: ['food_nutrient_conversion_factor_id', 'protein_value', 'fat_value', 'carbohydrate_value', 'source_file']
# Columns in food_category.csv: ['id', 'code', 'description', 'source_file']
# Columns in food_component.csv: ['id', 'fdc_id', 'name', 'pct_weight', 'is_refuse', 'gram_weight', 'data_points', 'min_year_acqured', 'source_file']
# Columns in food_nutrient_conversion_factor.csv: ['id', 'fdc_id', 'source_file']
# Columns in food_nutrient.csv: ['id', 'fdc_id', 'nutrient_id', 'amount', 'data_points', 'derivation_id', 'min', 'max', 'median', 'footnote', 'min_year_acquired', 'source_file']
# Columns in food_portion.csv: ['id', 'fdc_id', 'seq_num', 'amount', 'measure_unit_id', 'portion_description', 'modifier', 'gram_weight', 'data_points', 'footnote', 'min_year_acquired', 'source_file']
# Columns in food_protein_conversion_factor.csv: ['food_nutrient_conversion_factor_id', 'value', 'source_file']
# Columns in food_update_log_entry.csv: ['id', 'description', 'last_updated', 'source_file']
# Columns in food.csv: ['fdc_id', 'data_type', 'description', 'food_category_id', 'publication_date', 'source_file']
# Columns in foundation_food.csv: ['fdc_id', 'NDB_number', 'footnote', 'source_file']
# Columns in input_food.csv: ['id', 'fdc_id', 'fdc_of_input_food', 'seq_num', 'amount', 'sr_code', 'sr_description', 'unit', 'portion_code', 'portion_description', 'gram_weight', 'retention_code', 'survey_flag', 'source_file']
# Columns in lab_method_code.csv: ['lab_method_id', 'code', 'source_file']
# Columns in lab_method_nutrient.csv: ['lab_method_id', 'nutrient_id', 'source_file']
# Columns in lab_method.csv: ['id', 'description', 'technique', 'source_file']
# Columns in market_acquisition.csv: ['fdc_id', 'brand_description', 'expiration_date', 'label_weight', 'location', 'acquisition_date', 'sales_type', 'sample_lot_nbr', 'sell_by_date', 'store_city', 'store_name', 'store_state', 'upc_code', 'source_file']
# Columns in measure_unit.csv: ['id', 'name', 'source_file']
# Columns in nutrient.csv: ['id', 'name', 'unit_name', 'nutrient_nbr', 'rank', 'source_file']
# Columns in sample_food.csv: ['fdc_id', 'source_file']
# Columns in sub_sample_food.csv: ['fdc_id', 'fdc_id_of_sample_food', 'source_file']
# Columns in sub_sample_result.csv: ['food_nutrient_id', 'adjusted_amount', 'lab_method_id', 'nutrient_name', 'source_file']
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# <ipython-input-31-8035e0c61c70>:57: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Unknown', inplace=True)  # Fill missing values
# Combined DataFrame shape: (494100, 67)
# Sample data from combined DataFrame:
#    fdc_id_of_sample_food  fdc_id_of_acquisition_food              source_file  \
# 0               319874.0                    319876.0  acquisition_samples.csv
# 1               319874.0                    319875.0  acquisition_samples.csv
# 2               319879.0                    319881.0  acquisition_samples.csv
# 3               319879.0                    319880.0  acquisition_samples.csv
# 4               319885.0                    319890.0  acquisition_samples.csv
#
#                                                 text fdc_id acquisition_date  \
# 0  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...    NaN              NaN
# 1  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...    NaN              NaN
# 2  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...    NaN              NaN
# 3  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...    NaN              NaN
# 4  fdc_id_of_sample_food: 319885 fdc_id_of_acquis...    NaN              NaN
#
#   market_class treatment state  id  ... store_city store_name store_state  \
# 0          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 1          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 2          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 3          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 4          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
#
#   upc_code unit_name  nutrient_nbr  rank  food_nutrient_id  adjusted_amount  \
# 0      NaN       NaN           NaN   NaN               NaN              NaN
# 1      NaN       NaN           NaN   NaN               NaN              NaN
# 2      NaN       NaN           NaN   NaN               NaN              NaN
# 3      NaN       NaN           NaN   NaN               NaN              NaN
# 4      NaN       NaN           NaN   NaN               NaN              NaN
#
#   nutrient_name
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ## Prcoessing & Sampling

# %%
# Inspection: Data from each source file
print("\nData from each source file:")
for file in combined_df['source_file'].unique():
    print(f"\nSample from {file}:")
    print(combined_df[combined_df['source_file'] == file].head())
# Out:
# Data from each source file:
#
# Sample from acquisition_samples.csv:
#    fdc_id_of_sample_food  fdc_id_of_acquisition_food              source_file  \
# 0               319874.0                    319876.0  acquisition_samples.csv
# 1               319874.0                    319875.0  acquisition_samples.csv
# 2               319879.0                    319881.0  acquisition_samples.csv
# 3               319879.0                    319880.0  acquisition_samples.csv
# 4               319885.0                    319890.0  acquisition_samples.csv
#
#                                                 text fdc_id acquisition_date  \
# 0  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...    NaN              NaN
# 1  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...    NaN              NaN
# 2  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...    NaN              NaN
# 3  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...    NaN              NaN
# 4  fdc_id_of_sample_food: 319885 fdc_id_of_acquis...    NaN              NaN
#
#   market_class treatment state  id  ... store_city store_name store_state  \
# 0          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 1          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 2          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 3          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
# 4          NaN       NaN   NaN NaN  ...        NaN        NaN         NaN
#
#   upc_code unit_name  nutrient_nbr  rank  food_nutrient_id  adjusted_amount  \
# 0      NaN       NaN           NaN   NaN               NaN              NaN
# 1      NaN       NaN           NaN   NaN               NaN              NaN
# 2      NaN       NaN           NaN   NaN               NaN              NaN
# 3      NaN       NaN           NaN   NaN               NaN              NaN
# 4      NaN       NaN           NaN   NaN               NaN              NaN
#
#   nutrient_name
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 67 columns]
#
# Sample from agricultural_samples.csv:
#       fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 7593                    NaN                         NaN
# 7594                    NaN                         NaN
# 7595                    NaN                         NaN
# 7596                    NaN                         NaN
# 7597                    NaN                         NaN
#
#                    source_file  \
# 7593  agricultural_samples.csv
# 7594  agricultural_samples.csv
# 7595  agricultural_samples.csv
# 7596  agricultural_samples.csv
# 7597  agricultural_samples.csv
#
#                                                    text    fdc_id  \
# 7593  fdc_id: 335241 acquisition_date: 2016-11-11 ma...  335241.0
# 7594  fdc_id: 335242 acquisition_date: 2016-11-11 ma...  335242.0
# 7595  fdc_id: 335243 acquisition_date: 2016-11-11 ma...  335243.0
# 7596  fdc_id: 335244 acquisition_date: 2016-11-11 ma...  335244.0
# 7597  fdc_id: 335246 acquisition_date: 2016-11-11 ma...  335246.0
#
#      acquisition_date     market_class treatment state  id  ... store_city  \
# 7593       2016-11-11  Dark Red Kidney   Control    PR NaN  ...        NaN
# 7594       2016-11-11  Dark Red Kidney   Control    PR NaN  ...        NaN
# 7595       2016-11-11  Dark Red Kidney   Control    PR NaN  ...        NaN
# 7596       2016-11-11  Dark Red Kidney   Control    PR NaN  ...        NaN
# 7597       2016-11-11             Pink   Control    PR NaN  ...        NaN
#
#      store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 7593        NaN         NaN      NaN       NaN           NaN   NaN
# 7594        NaN         NaN      NaN       NaN           NaN   NaN
# 7595        NaN         NaN      NaN       NaN           NaN   NaN
# 7596        NaN         NaN      NaN       NaN           NaN   NaN
# 7597        NaN         NaN      NaN       NaN           NaN   NaN
#
#       food_nutrient_id  adjusted_amount nutrient_name
# 7593               NaN              NaN           NaN
# 7594               NaN              NaN           NaN
# 7595               NaN              NaN           NaN
# 7596               NaN              NaN           NaN
# 7597               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_attribute_type.csv:
#       fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 8403                    NaN                         NaN
# 8404                    NaN                         NaN
# 8405                    NaN                         NaN
# 8406                    NaN                         NaN
# 8407                    NaN                         NaN
#
#                   source_file  \
# 8403  food_attribute_type.csv
# 8404  food_attribute_type.csv
# 8405  food_attribute_type.csv
# 8406  food_attribute_type.csv
# 8407  food_attribute_type.csv
#
#                                                    text fdc_id  \
# 8403  id: 998 name: Update Log description: Changes ...    NaN
# 8404  id: 999 name: Attribute description: Generic a...    NaN
# 8405  id: 1000 name: Common Name description: Common...    NaN
# 8406  id: 1001 name: Additional Description descript...    NaN
# 8407  id: 1002 name: Adjustments description: Adjust...    NaN
#
#      acquisition_date market_class treatment state      id  ... store_city  \
# 8403              NaN          NaN       NaN   NaN   998.0  ...        NaN
# 8404              NaN          NaN       NaN   NaN   999.0  ...        NaN
# 8405              NaN          NaN       NaN   NaN  1000.0  ...        NaN
# 8406              NaN          NaN       NaN   NaN  1001.0  ...        NaN
# 8407              NaN          NaN       NaN   NaN  1002.0  ...        NaN
#
#      store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 8403        NaN         NaN      NaN       NaN           NaN   NaN
# 8404        NaN         NaN      NaN       NaN           NaN   NaN
# 8405        NaN         NaN      NaN       NaN           NaN   NaN
# 8406        NaN         NaN      NaN       NaN           NaN   NaN
# 8407        NaN         NaN      NaN       NaN           NaN   NaN
#
#       food_nutrient_id  adjusted_amount nutrient_name
# 8403               NaN              NaN           NaN
# 8404               NaN              NaN           NaN
# 8405               NaN              NaN           NaN
# 8406               NaN              NaN           NaN
# 8407               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_attribute.csv:
#       fdc_id_of_sample_food  fdc_id_of_acquisition_food         source_file  \
# 8408                    NaN                         NaN  food_attribute.csv
# 8409                    NaN                         NaN  food_attribute.csv
# 8410                    NaN                         NaN  food_attribute.csv
# 8411                    NaN                         NaN  food_attribute.csv
# 8412                    NaN                         NaN  food_attribute.csv
#
#                                                    text    fdc_id  \
# 8408  id: 3225143 fdc_id: 321358 seq_num: Unknown fo...  321358.0
# 8409  id: 3225142 fdc_id: 321358 seq_num: Unknown fo...  321358.0
# 8410  id: 3225141 fdc_id: 321358 seq_num: Unknown fo...  321358.0
# 8411  id: 3225140 fdc_id: 321358 seq_num: Unknown fo...  321358.0
# 8412  id: 3225139 fdc_id: 321358 seq_num: Unknown fo...  321358.0
#
#      acquisition_date market_class treatment state         id  ... store_city  \
# 8408              NaN          NaN       NaN   NaN  3225143.0  ...        NaN
# 8409              NaN          NaN       NaN   NaN  3225142.0  ...        NaN
# 8410              NaN          NaN       NaN   NaN  3225141.0  ...        NaN
# 8411              NaN          NaN       NaN   NaN  3225140.0  ...        NaN
# 8412              NaN          NaN       NaN   NaN  3225139.0  ...        NaN
#
#      store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 8408        NaN         NaN      NaN       NaN           NaN   NaN
# 8409        NaN         NaN      NaN       NaN           NaN   NaN
# 8410        NaN         NaN      NaN       NaN           NaN   NaN
# 8411        NaN         NaN      NaN       NaN           NaN   NaN
# 8412        NaN         NaN      NaN       NaN           NaN   NaN
#
#       food_nutrient_id  adjusted_amount nutrient_name
# 8408               NaN              NaN           NaN
# 8409               NaN              NaN           NaN
# 8410               NaN              NaN           NaN
# 8411               NaN              NaN           NaN
# 8412               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_calorie_conversion_factor.csv:
#        fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 14033                    NaN                         NaN
# 14034                    NaN                         NaN
# 14035                    NaN                         NaN
# 14036                    NaN                         NaN
# 14037                    NaN                         NaN
#
#                               source_file  \
# 14033  food_calorie_conversion_factor.csv
# 14034  food_calorie_conversion_factor.csv
# 14035  food_calorie_conversion_factor.csv
# 14036  food_calorie_conversion_factor.csv
# 14037  food_calorie_conversion_factor.csv
#
#                                                     text fdc_id  \
# 14033  food_nutrient_conversion_factor_id: 22503 prot...    NaN
# 14034  food_nutrient_conversion_factor_id: 22505 prot...    NaN
# 14035  food_nutrient_conversion_factor_id: 22507 prot...    NaN
# 14036  food_nutrient_conversion_factor_id: 22510 prot...    NaN
# 14037  food_nutrient_conversion_factor_id: 22512 prot...    NaN
#
#       acquisition_date market_class treatment state  id  ... store_city  \
# 14033              NaN          NaN       NaN   NaN NaN  ...        NaN
# 14034              NaN          NaN       NaN   NaN NaN  ...        NaN
# 14035              NaN          NaN       NaN   NaN NaN  ...        NaN
# 14036              NaN          NaN       NaN   NaN NaN  ...        NaN
# 14037              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#       store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 14033        NaN         NaN      NaN       NaN           NaN   NaN
# 14034        NaN         NaN      NaN       NaN           NaN   NaN
# 14035        NaN         NaN      NaN       NaN           NaN   NaN
# 14036        NaN         NaN      NaN       NaN           NaN   NaN
# 14037        NaN         NaN      NaN       NaN           NaN   NaN
#
#        food_nutrient_id  adjusted_amount nutrient_name
# 14033               NaN              NaN           NaN
# 14034               NaN              NaN           NaN
# 14035               NaN              NaN           NaN
# 14036               NaN              NaN           NaN
# 14037               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_category.csv:
#        fdc_id_of_sample_food  fdc_id_of_acquisition_food        source_file  \
# 14345                    NaN                         NaN  food_category.csv
# 14346                    NaN                         NaN  food_category.csv
# 14347                    NaN                         NaN  food_category.csv
# 14348                    NaN                         NaN  food_category.csv
# 14349                    NaN                         NaN  food_category.csv
#
#                                                     text fdc_id  \
# 14345  id: 1 code: 100 description: Dairy and Egg Pro...    NaN
# 14346  id: 2 code: 200 description: Spices and Herbs ...    NaN
# 14347  id: 3 code: 300 description: Baby Foods source...    NaN
# 14348  id: 4 code: 400 description: Fats and Oils sou...    NaN
# 14349  id: 5 code: 500 description: Poultry Products ...    NaN
#
#       acquisition_date market_class treatment state   id  ... store_city  \
# 14345              NaN          NaN       NaN   NaN  1.0  ...        NaN
# 14346              NaN          NaN       NaN   NaN  2.0  ...        NaN
# 14347              NaN          NaN       NaN   NaN  3.0  ...        NaN
# 14348              NaN          NaN       NaN   NaN  4.0  ...        NaN
# 14349              NaN          NaN       NaN   NaN  5.0  ...        NaN
#
#       store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 14345        NaN         NaN      NaN       NaN           NaN   NaN
# 14346        NaN         NaN      NaN       NaN           NaN   NaN
# 14347        NaN         NaN      NaN       NaN           NaN   NaN
# 14348        NaN         NaN      NaN       NaN           NaN   NaN
# 14349        NaN         NaN      NaN       NaN           NaN   NaN
#
#        food_nutrient_id  adjusted_amount nutrient_name
# 14345               NaN              NaN           NaN
# 14346               NaN              NaN           NaN
# 14347               NaN              NaN           NaN
# 14348               NaN              NaN           NaN
# 14349               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_component.csv:
#        fdc_id_of_sample_food  fdc_id_of_acquisition_food         source_file  \
# 14373                    NaN                         NaN  food_component.csv
# 14374                    NaN                         NaN  food_component.csv
# 14375                    NaN                         NaN  food_component.csv
# 14376                    NaN                         NaN  food_component.csv
# 14377                    NaN                         NaN  food_component.csv
#
#                                                     text   fdc_id  \
# 14373  id: 56885 fdc_id: Unknown name: Bone and conne...  Unknown
# 14374  id: 56886 fdc_id: Unknown name: External fat p...  Unknown
# 14375  id: 56887 fdc_id: Unknown name: Handling loss ...  Unknown
# 14376  id: 56888 fdc_id: Unknown name: Seam fat pct_w...  Unknown
# 14377  id: 56889 fdc_id: Unknown name: Separable Lean...  Unknown
#
#       acquisition_date market_class treatment state       id  ... store_city  \
# 14373              NaN          NaN       NaN   NaN  56885.0  ...        NaN
# 14374              NaN          NaN       NaN   NaN  56886.0  ...        NaN
# 14375              NaN          NaN       NaN   NaN  56887.0  ...        NaN
# 14376              NaN          NaN       NaN   NaN  56888.0  ...        NaN
# 14377              NaN          NaN       NaN   NaN  56889.0  ...        NaN
#
#       store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 14373        NaN         NaN      NaN       NaN           NaN   NaN
# 14374        NaN         NaN      NaN       NaN           NaN   NaN
# 14375        NaN         NaN      NaN       NaN           NaN   NaN
# 14376        NaN         NaN      NaN       NaN           NaN   NaN
# 14377        NaN         NaN      NaN       NaN           NaN   NaN
#
#        food_nutrient_id  adjusted_amount nutrient_name
# 14373               NaN              NaN           NaN
# 14374               NaN              NaN           NaN
# 14375               NaN              NaN           NaN
# 14376               NaN              NaN           NaN
# 14377               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_nutrient_conversion_factor.csv:
#        fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 17439                    NaN                         NaN
# 17440                    NaN                         NaN
# 17441                    NaN                         NaN
# 17442                    NaN                         NaN
# 17443                    NaN                         NaN
#
#                                source_file  \
# 17439  food_nutrient_conversion_factor.csv
# 17440  food_nutrient_conversion_factor.csv
# 17441  food_nutrient_conversion_factor.csv
# 17442  food_nutrient_conversion_factor.csv
# 17443  food_nutrient_conversion_factor.csv
#
#                                                     text  fdc_id  \
# 17439  id: 22721 fdc_id: 746952 source_file: food_nut...  746952
# 17440  id: 22722 fdc_id: 747429 source_file: food_nut...  747429
# 17441  id: 22723 fdc_id: 747693 source_file: food_nut...  747693
# 17442  id: 22724 fdc_id: 749420 source_file: food_nut...  749420
# 17443  id: 22725 fdc_id: 789890 source_file: food_nut...  789890
#
#       acquisition_date market_class treatment state       id  ... store_city  \
# 17439              NaN          NaN       NaN   NaN  22721.0  ...        NaN
# 17440              NaN          NaN       NaN   NaN  22722.0  ...        NaN
# 17441              NaN          NaN       NaN   NaN  22723.0  ...        NaN
# 17442              NaN          NaN       NaN   NaN  22724.0  ...        NaN
# 17443              NaN          NaN       NaN   NaN  22725.0  ...        NaN
#
#       store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 17439        NaN         NaN      NaN       NaN           NaN   NaN
# 17440        NaN         NaN      NaN       NaN           NaN   NaN
# 17441        NaN         NaN      NaN       NaN           NaN   NaN
# 17442        NaN         NaN      NaN       NaN           NaN   NaN
# 17443        NaN         NaN      NaN       NaN           NaN   NaN
#
#        food_nutrient_id  adjusted_amount nutrient_name
# 17439               NaN              NaN           NaN
# 17440               NaN              NaN           NaN
# 17441               NaN              NaN           NaN
# 17442               NaN              NaN           NaN
# 17443               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_nutrient.csv:
#        fdc_id_of_sample_food  fdc_id_of_acquisition_food        source_file  \
# 28809                    NaN                         NaN  food_nutrient.csv
# 28810                    NaN                         NaN  food_nutrient.csv
# 28811                    NaN                         NaN  food_nutrient.csv
# 28812                    NaN                         NaN  food_nutrient.csv
# 28813                    NaN                         NaN  food_nutrient.csv
#
#                                                     text  fdc_id  \
# 28809  id: 2201847 fdc_id: 319877 nutrient_id: 1051 a...  319877
# 28810  id: 2201845 fdc_id: 319877 nutrient_id: 1002 a...  319877
# 28811  id: 2201846 fdc_id: 319877 nutrient_id: 1004 a...  319877
# 28812  id: 2201844 fdc_id: 319877 nutrient_id: 1007 a...  319877
# 28813  id: 2201852 fdc_id: 319878 nutrient_id: 1091 a...  319878
#
#       acquisition_date market_class treatment state         id  ...  \
# 28809              NaN          NaN       NaN   NaN  2201847.0  ...
# 28810              NaN          NaN       NaN   NaN  2201845.0  ...
# 28811              NaN          NaN       NaN   NaN  2201846.0  ...
# 28812              NaN          NaN       NaN   NaN  2201844.0  ...
# 28813              NaN          NaN       NaN   NaN  2201852.0  ...
#
#       store_city store_name store_state upc_code unit_name  nutrient_nbr  \
# 28809        NaN        NaN         NaN      NaN       NaN           NaN
# 28810        NaN        NaN         NaN      NaN       NaN           NaN
# 28811        NaN        NaN         NaN      NaN       NaN           NaN
# 28812        NaN        NaN         NaN      NaN       NaN           NaN
# 28813        NaN        NaN         NaN      NaN       NaN           NaN
#
#        rank  food_nutrient_id  adjusted_amount nutrient_name
# 28809   NaN               NaN              NaN           NaN
# 28810   NaN               NaN              NaN           NaN
# 28811   NaN               NaN              NaN           NaN
# 28812   NaN               NaN              NaN           NaN
# 28813   NaN               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_portion.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food       source_file  \
# 173293                    NaN                         NaN  food_portion.csv
# 173294                    NaN                         NaN  food_portion.csv
# 173295                    NaN                         NaN  food_portion.csv
# 173296                    NaN                         NaN  food_portion.csv
# 173297                    NaN                         NaN  food_portion.csv
#
#                                                      text  fdc_id  \
# 173293  id: 118702 fdc_id: 319875 seq_num: Unknown amo...  319875
# 173294  id: 118703 fdc_id: 319880 seq_num: Unknown amo...  319880
# 173295  id: 118704 fdc_id: 319881 seq_num: Unknown amo...  319881
# 173296  id: 118705 fdc_id: 319886 seq_num: Unknown amo...  319886
# 173297  id: 118706 fdc_id: 319889 seq_num: Unknown amo...  319889
#
#        acquisition_date market_class treatment state        id  ...  \
# 173293              NaN          NaN       NaN   NaN  118702.0  ...
# 173294              NaN          NaN       NaN   NaN  118703.0  ...
# 173295              NaN          NaN       NaN   NaN  118704.0  ...
# 173296              NaN          NaN       NaN   NaN  118705.0  ...
# 173297              NaN          NaN       NaN   NaN  118706.0  ...
#
#        store_city store_name store_state upc_code unit_name  nutrient_nbr  \
# 173293        NaN        NaN         NaN      NaN       NaN           NaN
# 173294        NaN        NaN         NaN      NaN       NaN           NaN
# 173295        NaN        NaN         NaN      NaN       NaN           NaN
# 173296        NaN        NaN         NaN      NaN       NaN           NaN
# 173297        NaN        NaN         NaN      NaN       NaN           NaN
#
#         rank  food_nutrient_id  adjusted_amount nutrient_name
# 173293   NaN               NaN              NaN           NaN
# 173294   NaN               NaN              NaN           NaN
# 173295   NaN               NaN              NaN           NaN
# 173296   NaN               NaN              NaN           NaN
# 173297   NaN               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_protein_conversion_factor.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 183971                    NaN                         NaN
# 183972                    NaN                         NaN
# 183973                    NaN                         NaN
# 183974                    NaN                         NaN
# 183975                    NaN                         NaN
#
#                                source_file  \
# 183971  food_protein_conversion_factor.csv
# 183972  food_protein_conversion_factor.csv
# 183973  food_protein_conversion_factor.csv
# 183974  food_protein_conversion_factor.csv
# 183975  food_protein_conversion_factor.csv
#
#                                                      text fdc_id  \
# 183971  food_nutrient_conversion_factor_id: 22504 valu...    NaN
# 183972  food_nutrient_conversion_factor_id: 22506 valu...    NaN
# 183973  food_nutrient_conversion_factor_id: 22508 valu...    NaN
# 183974  food_nutrient_conversion_factor_id: 22509 valu...    NaN
# 183975  food_nutrient_conversion_factor_id: 22511 valu...    NaN
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 183971              NaN          NaN       NaN   NaN NaN  ...        NaN
# 183972              NaN          NaN       NaN   NaN NaN  ...        NaN
# 183973              NaN          NaN       NaN   NaN NaN  ...        NaN
# 183974              NaN          NaN       NaN   NaN NaN  ...        NaN
# 183975              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 183971        NaN         NaN      NaN       NaN           NaN   NaN
# 183972        NaN         NaN      NaN       NaN           NaN   NaN
# 183973        NaN         NaN      NaN       NaN           NaN   NaN
# 183974        NaN         NaN      NaN       NaN           NaN   NaN
# 183975        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 183971               NaN              NaN           NaN
# 183972               NaN              NaN           NaN
# 183973               NaN              NaN           NaN
# 183974               NaN              NaN           NaN
# 183975               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food_update_log_entry.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 184259                    NaN                         NaN
# 184260                    NaN                         NaN
# 184261                    NaN                         NaN
# 184262                    NaN                         NaN
# 184263                    NaN                         NaN
#
#                       source_file  \
# 184259  food_update_log_entry.csv
# 184260  food_update_log_entry.csv
# 184261  food_update_log_entry.csv
# 184262  food_update_log_entry.csv
# 184263  food_update_log_entry.csv
#
#                                                      text fdc_id  \
# 184259  id: 319874 description: HUMMUS, SABRA CLASSIC ...    NaN
# 184260  id: 319875 description: HUMMUS, SABRA CLASSIC ...    NaN
# 184261  id: 319876 description: HUMMUS, SABRA CLASSIC ...    NaN
# 184262  id: 319877 description: Hummus last_updated: 2...    NaN
# 184263  id: 319878 description: Hummus last_updated: 2...    NaN
#
#        acquisition_date market_class treatment state        id  ...  \
# 184259              NaN          NaN       NaN   NaN  319874.0  ...
# 184260              NaN          NaN       NaN   NaN  319875.0  ...
# 184261              NaN          NaN       NaN   NaN  319876.0  ...
# 184262              NaN          NaN       NaN   NaN  319877.0  ...
# 184263              NaN          NaN       NaN   NaN  319878.0  ...
#
#        store_city store_name store_state upc_code unit_name  nutrient_nbr  \
# 184259        NaN        NaN         NaN      NaN       NaN           NaN
# 184260        NaN        NaN         NaN      NaN       NaN           NaN
# 184261        NaN        NaN         NaN      NaN       NaN           NaN
# 184262        NaN        NaN         NaN      NaN       NaN           NaN
# 184263        NaN        NaN         NaN      NaN       NaN           NaN
#
#         rank  food_nutrient_id  adjusted_amount nutrient_name
# 184259   NaN               NaN              NaN           NaN
# 184260   NaN               NaN              NaN           NaN
# 184261   NaN               NaN              NaN           NaN
# 184262   NaN               NaN              NaN           NaN
# 184263   NaN               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from food.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food source_file  \
# 248234                    NaN                         NaN    food.csv
# 248235                    NaN                         NaN    food.csv
# 248236                    NaN                         NaN    food.csv
# 248237                    NaN                         NaN    food.csv
# 248238                    NaN                         NaN    food.csv
#
#                                                      text  fdc_id  \
# 248234  fdc_id: 319874 data_type: sample_food descript...  319874
# 248235  fdc_id: 319875 data_type: market_acquisition d...  319875
# 248236  fdc_id: 319876 data_type: market_acquisition d...  319876
# 248237  fdc_id: 319877 data_type: sub_sample_food desc...  319877
# 248238  fdc_id: 319878 data_type: sub_sample_food desc...  319878
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 248234              NaN          NaN       NaN   NaN NaN  ...        NaN
# 248235              NaN          NaN       NaN   NaN NaN  ...        NaN
# 248236              NaN          NaN       NaN   NaN NaN  ...        NaN
# 248237              NaN          NaN       NaN   NaN NaN  ...        NaN
# 248238              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 248234        NaN         NaN      NaN       NaN           NaN   NaN
# 248235        NaN         NaN      NaN       NaN           NaN   NaN
# 248236        NaN         NaN      NaN       NaN           NaN   NaN
# 248237        NaN         NaN      NaN       NaN           NaN   NaN
# 248238        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 248234               NaN              NaN           NaN
# 248235               NaN              NaN           NaN
# 248236               NaN              NaN           NaN
# 248237               NaN              NaN           NaN
# 248238               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from foundation_food.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 312209                    NaN                         NaN
# 312210                    NaN                         NaN
# 312211                    NaN                         NaN
# 312212                    NaN                         NaN
# 312213                    NaN                         NaN
#
#                 source_file  \
# 312209  foundation_food.csv
# 312210  foundation_food.csv
# 312211  foundation_food.csv
# 312212  foundation_food.csv
# 312213  foundation_food.csv
#
#                                                      text  fdc_id  \
# 312209  fdc_id: 321358 NDB_number: 16158 footnote: Unk...  321358
# 312210  fdc_id: 321360 NDB_number: 100147 footnote: Un...  321360
# 312211  fdc_id: 321611 NDB_number: 11056 footnote: Unk...  321611
# 312212  fdc_id: 323121 NDB_number: 7022 footnote: Unkn...  323121
# 312213  fdc_id: 323294 NDB_number: 12563 footnote:  Ot...  323294
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 312209              NaN          NaN       NaN   NaN NaN  ...        NaN
# 312210              NaN          NaN       NaN   NaN NaN  ...        NaN
# 312211              NaN          NaN       NaN   NaN NaN  ...        NaN
# 312212              NaN          NaN       NaN   NaN NaN  ...        NaN
# 312213              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 312209        NaN         NaN      NaN       NaN           NaN   NaN
# 312210        NaN         NaN      NaN       NaN           NaN   NaN
# 312211        NaN         NaN      NaN       NaN           NaN   NaN
# 312212        NaN         NaN      NaN       NaN           NaN   NaN
# 312213        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 312209               NaN              NaN           NaN
# 312210               NaN              NaN           NaN
# 312211               NaN              NaN           NaN
# 312212               NaN              NaN           NaN
# 312213               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from input_food.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food     source_file  \
# 312496                    NaN                         NaN  input_food.csv
# 312497                    NaN                         NaN  input_food.csv
# 312498                    NaN                         NaN  input_food.csv
# 312499                    NaN                         NaN  input_food.csv
# 312500                    NaN                         NaN  input_food.csv
#
#                                                      text  fdc_id  \
# 312496  id: 10437 fdc_id: 321358 fdc_of_input_food: 31...  321358
# 312497  id: 10438 fdc_id: 321358 fdc_of_input_food: 32...  321358
# 312498  id: 10434 fdc_id: 321358 fdc_of_input_food: 31...  321358
# 312499  id: 10430 fdc_id: 321358 fdc_of_input_food: 31...  321358
# 312500  id: 10431 fdc_id: 321358 fdc_of_input_food: 31...  321358
#
#        acquisition_date market_class treatment state       id  ... store_city  \
# 312496              NaN          NaN       NaN   NaN  10437.0  ...        NaN
# 312497              NaN          NaN       NaN   NaN  10438.0  ...        NaN
# 312498              NaN          NaN       NaN   NaN  10434.0  ...        NaN
# 312499              NaN          NaN       NaN   NaN  10430.0  ...        NaN
# 312500              NaN          NaN       NaN   NaN  10431.0  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 312496        NaN         NaN      NaN       NaN           NaN   NaN
# 312497        NaN         NaN      NaN       NaN           NaN   NaN
# 312498        NaN         NaN      NaN       NaN           NaN   NaN
# 312499        NaN         NaN      NaN       NaN           NaN   NaN
# 312500        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 312496               NaN              NaN           NaN
# 312497               NaN              NaN           NaN
# 312498               NaN              NaN           NaN
# 312499               NaN              NaN           NaN
# 312500               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from lab_method_code.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 317766                    NaN                         NaN
# 317767                    NaN                         NaN
# 317768                    NaN                         NaN
# 317769                    NaN                         NaN
# 317770                    NaN                         NaN
#
#                 source_file  \
# 317766  lab_method_code.csv
# 317767  lab_method_code.csv
# 317768  lab_method_code.csv
# 317769  lab_method_code.csv
# 317770  lab_method_code.csv
#
#                                                      text fdc_id  \
# 317766  lab_method_id: 1001 code: DGEN_S source_file: ...    NaN
# 317767  lab_method_id: 1003 code: FAT-MJ-FLT-CHG sourc...    NaN
# 317768  lab_method_id: 1003 code: FAT_AH_S source_file...    NaN
# 317769  lab_method_id: 1004 code: ASHM_S source_file: ...    NaN
# 317770  lab_method_id: 1005 code: SUGN_S source_file: ...    NaN
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 317766              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317767              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317768              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317769              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317770              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 317766        NaN         NaN      NaN       NaN           NaN   NaN
# 317767        NaN         NaN      NaN       NaN           NaN   NaN
# 317768        NaN         NaN      NaN       NaN           NaN   NaN
# 317769        NaN         NaN      NaN       NaN           NaN   NaN
# 317770        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 317766               NaN              NaN           NaN
# 317767               NaN              NaN           NaN
# 317768               NaN              NaN           NaN
# 317769               NaN              NaN           NaN
# 317770               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from lab_method_nutrient.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 317955                    NaN                         NaN
# 317956                    NaN                         NaN
# 317957                    NaN                         NaN
# 317958                    NaN                         NaN
# 317959                    NaN                         NaN
#
#                     source_file  \
# 317955  lab_method_nutrient.csv
# 317956  lab_method_nutrient.csv
# 317957  lab_method_nutrient.csv
# 317958  lab_method_nutrient.csv
# 317959  lab_method_nutrient.csv
#
#                                                      text fdc_id  \
# 317955  lab_method_id: 1001 nutrient_id: 1002 source_f...    NaN
# 317956  lab_method_id: 1001 nutrient_id: 1003 source_f...    NaN
# 317957  lab_method_id: 1003 nutrient_id: 1004 source_f...    NaN
# 317958  lab_method_id: 1004 nutrient_id: 1007 source_f...    NaN
# 317959  lab_method_id: 1005 nutrient_id: 1011 source_f...    NaN
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 317955              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317956              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317957              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317958              NaN          NaN       NaN   NaN NaN  ...        NaN
# 317959              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 317955        NaN         NaN      NaN       NaN           NaN   NaN
# 317956        NaN         NaN      NaN       NaN           NaN   NaN
# 317957        NaN         NaN      NaN       NaN           NaN   NaN
# 317958        NaN         NaN      NaN       NaN           NaN   NaN
# 317959        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 317955               NaN              NaN           NaN
# 317956               NaN              NaN           NaN
# 317957               NaN              NaN           NaN
# 317958               NaN              NaN           NaN
# 317959               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from lab_method.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food     source_file  \
# 318515                    NaN                         NaN  lab_method.csv
# 318516                    NaN                         NaN  lab_method.csv
# 318517                    NaN                         NaN  lab_method.csv
# 318518                    NaN                         NaN  lab_method.csv
# 318519                    NaN                         NaN  lab_method.csv
#
#                                                      text fdc_id  \
# 318515  id: 1000 description: NIST Handbook 133 techni...    NaN
# 318516  id: 1001 description: AOAC 968.06 + 992.15 tec...    NaN
# 318517  id: 1002 description: AOAC 960.39 39.1 techniq...    NaN
# 318518  id: 1003 description: AOAC 922.06 technique: A...    NaN
# 318519  id: 1004 description: AOAC 923.03 technique: G...    NaN
#
#        acquisition_date market_class treatment state      id  ... store_city  \
# 318515              NaN          NaN       NaN   NaN  1000.0  ...        NaN
# 318516              NaN          NaN       NaN   NaN  1001.0  ...        NaN
# 318517              NaN          NaN       NaN   NaN  1002.0  ...        NaN
# 318518              NaN          NaN       NaN   NaN  1003.0  ...        NaN
# 318519              NaN          NaN       NaN   NaN  1004.0  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 318515        NaN         NaN      NaN       NaN           NaN   NaN
# 318516        NaN         NaN      NaN       NaN           NaN   NaN
# 318517        NaN         NaN      NaN       NaN           NaN   NaN
# 318518        NaN         NaN      NaN       NaN           NaN   NaN
# 318519        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 318515               NaN              NaN           NaN
# 318516               NaN              NaN           NaN
# 318517               NaN              NaN           NaN
# 318518               NaN              NaN           NaN
# 318519               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from market_acquisition.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 318795                    NaN                         NaN
# 318796                    NaN                         NaN
# 318797                    NaN                         NaN
# 318798                    NaN                         NaN
# 318799                    NaN                         NaN
#
#                    source_file  \
# 318795  market_acquisition.csv
# 318796  market_acquisition.csv
# 318797  market_acquisition.csv
# 318798  market_acquisition.csv
# 318799  market_acquisition.csv
#
#                                                      text  fdc_id  \
# 318795  fdc_id: 319875 brand_description: Unknown expi...  319875
# 318796  fdc_id: 319876 brand_description: Unknown expi...  319876
# 318797  fdc_id: 319880 brand_description: Unknown expi...  319880
# 318798  fdc_id: 319881 brand_description: Unknown expi...  319881
# 318799  fdc_id: 319886 brand_description: Unknown expi...  319886
#
#        acquisition_date market_class treatment state  id  ...   store_city  \
# 318795       2015-10-06          NaN       NaN   NaN NaN  ...     HASTINGS
# 318796       2015-10-06          NaN       NaN   NaN NaN  ...     HASTINGS
# 318797       2015-09-27          NaN       NaN   NaN NaN  ...   PITTSBURGH
# 318798       2015-09-27          NaN       NaN   NaN NaN  ...       TUCSON
# 318799       2015-09-19          NaN       NaN   NaN NaN  ...  ESTHERVILLE
#
#                store_name store_state     upc_code unit_name  nutrient_nbr  \
# 318795   ALLENS FOOD MART          NE  40822011143       NaN           NaN
# 318796   ALLENS FOOD MART          NE  40822011143       NaN           NaN
# 318797        SHOP N SAVE          PA  40822011143       NaN           NaN
# 318798      BASHAS MARKET          AZ  40822011143       NaN           NaN
# 318799  HY VEE FOOD STORE          IA  40822011143       NaN           NaN
#
#         rank  food_nutrient_id  adjusted_amount nutrient_name
# 318795   NaN               NaN              NaN           NaN
# 318796   NaN               NaN              NaN           NaN
# 318797   NaN               NaN              NaN           NaN
# 318798   NaN               NaN              NaN           NaN
# 318799   NaN               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from measure_unit.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food       source_file  \
# 325604                    NaN                         NaN  measure_unit.csv
# 325605                    NaN                         NaN  measure_unit.csv
# 325606                    NaN                         NaN  measure_unit.csv
# 325607                    NaN                         NaN  measure_unit.csv
# 325608                    NaN                         NaN  measure_unit.csv
#
#                                                      text fdc_id  \
# 325604   id: 1000 name: cup source_file: measure_unit.csv    NaN
# 325605  id: 1001 name: tablespoon source_file: measure...    NaN
# 325606  id: 1002 name: teaspoon source_file: measure_u...    NaN
# 325607  id: 1003 name: liter source_file: measure_unit...    NaN
# 325608  id: 1004 name: milliliter source_file: measure...    NaN
#
#        acquisition_date market_class treatment state      id  ... store_city  \
# 325604              NaN          NaN       NaN   NaN  1000.0  ...        NaN
# 325605              NaN          NaN       NaN   NaN  1001.0  ...        NaN
# 325606              NaN          NaN       NaN   NaN  1002.0  ...        NaN
# 325607              NaN          NaN       NaN   NaN  1003.0  ...        NaN
# 325608              NaN          NaN       NaN   NaN  1004.0  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 325604        NaN         NaN      NaN       NaN           NaN   NaN
# 325605        NaN         NaN      NaN       NaN           NaN   NaN
# 325606        NaN         NaN      NaN       NaN           NaN   NaN
# 325607        NaN         NaN      NaN       NaN           NaN   NaN
# 325608        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 325604               NaN              NaN           NaN
# 325605               NaN              NaN           NaN
# 325606               NaN              NaN           NaN
# 325607               NaN              NaN           NaN
# 325608               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from nutrient.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food   source_file  \
# 325726                    NaN                         NaN  nutrient.csv
# 325727                    NaN                         NaN  nutrient.csv
# 325728                    NaN                         NaN  nutrient.csv
# 325729                    NaN                         NaN  nutrient.csv
# 325730                    NaN                         NaN  nutrient.csv
#
#                                                      text fdc_id  \
# 325726  id: 2047 name: Energy (Atwater General Factors...    NaN
# 325727  id: 2048 name: Energy (Atwater Specific Factor...    NaN
# 325728  id: 1001 name: Solids unit_name: G nutrient_nb...    NaN
# 325729  id: 1002 name: Nitrogen unit_name: G nutrient_...    NaN
# 325730  id: 1003 name: Protein unit_name: G nutrient_n...    NaN
#
#        acquisition_date market_class treatment state      id  ... store_city  \
# 325726              NaN          NaN       NaN   NaN  2047.0  ...        NaN
# 325727              NaN          NaN       NaN   NaN  2048.0  ...        NaN
# 325728              NaN          NaN       NaN   NaN  1001.0  ...        NaN
# 325729              NaN          NaN       NaN   NaN  1002.0  ...        NaN
# 325730              NaN          NaN       NaN   NaN  1003.0  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr   rank  \
# 325726        NaN         NaN      NaN      KCAL         957.0  280.0
# 325727        NaN         NaN      NaN      KCAL         958.0  290.0
# 325728        NaN         NaN      NaN         G         201.0  200.0
# 325729        NaN         NaN      NaN         G         202.0  500.0
# 325730        NaN         NaN      NaN         G         203.0  600.0
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 325726               NaN              NaN           NaN
# 325727               NaN              NaN           NaN
# 325728               NaN              NaN           NaN
# 325729               NaN              NaN           NaN
# 325730               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from sample_food.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food      source_file  \
# 326203                    NaN                         NaN  sample_food.csv
# 326204                    NaN                         NaN  sample_food.csv
# 326205                    NaN                         NaN  sample_food.csv
# 326206                    NaN                         NaN  sample_food.csv
# 326207                    NaN                         NaN  sample_food.csv
#
#                                                text  fdc_id acquisition_date  \
# 326203  fdc_id: 319874 source_file: sample_food.csv  319874              NaN
# 326204  fdc_id: 319879 source_file: sample_food.csv  319879              NaN
# 326205  fdc_id: 319885 source_file: sample_food.csv  319885              NaN
# 326206  fdc_id: 319894 source_file: sample_food.csv  319894              NaN
# 326207  fdc_id: 319901 source_file: sample_food.csv  319901              NaN
#
#        market_class treatment state  id  ... store_city store_name  \
# 326203          NaN       NaN   NaN NaN  ...        NaN        NaN
# 326204          NaN       NaN   NaN NaN  ...        NaN        NaN
# 326205          NaN       NaN   NaN NaN  ...        NaN        NaN
# 326206          NaN       NaN   NaN NaN  ...        NaN        NaN
# 326207          NaN       NaN   NaN NaN  ...        NaN        NaN
#
#        store_state upc_code unit_name  nutrient_nbr  rank  food_nutrient_id  \
# 326203         NaN      NaN       NaN           NaN   NaN               NaN
# 326204         NaN      NaN       NaN           NaN   NaN               NaN
# 326205         NaN      NaN       NaN           NaN   NaN               NaN
# 326206         NaN      NaN       NaN           NaN   NaN               NaN
# 326207         NaN      NaN       NaN           NaN   NaN               NaN
#
#         adjusted_amount nutrient_name
# 326203              NaN           NaN
# 326204              NaN           NaN
# 326205              NaN           NaN
# 326206              NaN           NaN
# 326207              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from sub_sample_food.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 329514               319874.0                         NaN
# 329515               319874.0                         NaN
# 329516               319879.0                         NaN
# 329517               319879.0                         NaN
# 329518               319879.0                         NaN
#
#                 source_file  \
# 329514  sub_sample_food.csv
# 329515  sub_sample_food.csv
# 329516  sub_sample_food.csv
# 329517  sub_sample_food.csv
# 329518  sub_sample_food.csv
#
#                                                      text  fdc_id  \
# 329514  fdc_id: 319877 fdc_id_of_sample_food: 319874 s...  319877
# 329515  fdc_id: 319878 fdc_id_of_sample_food: 319874 s...  319878
# 329516  fdc_id: 319882 fdc_id_of_sample_food: 319879 s...  319882
# 329517  fdc_id: 319883 fdc_id_of_sample_food: 319879 s...  319883
# 329518  fdc_id: 319884 fdc_id_of_sample_food: 319879 s...  319884
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 329514              NaN          NaN       NaN   NaN NaN  ...        NaN
# 329515              NaN          NaN       NaN   NaN NaN  ...        NaN
# 329516              NaN          NaN       NaN   NaN NaN  ...        NaN
# 329517              NaN          NaN       NaN   NaN NaN  ...        NaN
# 329518              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 329514        NaN         NaN      NaN       NaN           NaN   NaN
# 329515        NaN         NaN      NaN       NaN           NaN   NaN
# 329516        NaN         NaN      NaN       NaN           NaN   NaN
# 329517        NaN         NaN      NaN       NaN           NaN   NaN
# 329518        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount nutrient_name
# 329514               NaN              NaN           NaN
# 329515               NaN              NaN           NaN
# 329516               NaN              NaN           NaN
# 329517               NaN              NaN           NaN
# 329518               NaN              NaN           NaN
#
# [5 rows x 67 columns]
#
# Sample from sub_sample_result.csv:
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 382201                    NaN                         NaN
# 382202                    NaN                         NaN
# 382203                    NaN                         NaN
# 382204                    NaN                         NaN
# 382205                    NaN                         NaN
#
#                   source_file  \
# 382201  sub_sample_result.csv
# 382202  sub_sample_result.csv
# 382203  sub_sample_result.csv
# 382204  sub_sample_result.csv
# 382205  sub_sample_result.csv
#
#                                                      text fdc_id  \
# 382201  food_nutrient_id: 2201844 adjusted_amount: 1.9...    NaN
# 382202  food_nutrient_id: 2201845 adjusted_amount: 1.2...    NaN
# 382203  food_nutrient_id: 2201846 adjusted_amount: 19....    NaN
# 382204  food_nutrient_id: 2201847 adjusted_amount: 56....    NaN
# 382205  food_nutrient_id: 2201848 adjusted_amount: 46....    NaN
#
#        acquisition_date market_class treatment state  id  ... store_city  \
# 382201              NaN          NaN       NaN   NaN NaN  ...        NaN
# 382202              NaN          NaN       NaN   NaN NaN  ...        NaN
# 382203              NaN          NaN       NaN   NaN NaN  ...        NaN
# 382204              NaN          NaN       NaN   NaN NaN  ...        NaN
# 382205              NaN          NaN       NaN   NaN NaN  ...        NaN
#
#        store_name store_state upc_code unit_name  nutrient_nbr  rank  \
# 382201        NaN         NaN      NaN       NaN           NaN   NaN
# 382202        NaN         NaN      NaN       NaN           NaN   NaN
# 382203        NaN         NaN      NaN       NaN           NaN   NaN
# 382204        NaN         NaN      NaN       NaN           NaN   NaN
# 382205        NaN         NaN      NaN       NaN           NaN   NaN
#
#         food_nutrient_id  adjusted_amount      nutrient_name
# 382201         2201844.0             1.98                Ash
# 382202         2201845.0             1.28  Nitrogen by Dumas
# 382203         2201846.0             19.0                Fat
# 382204         2201847.0             56.3           Moisture
# 382205         2201848.0             46.2            Calcium
#
# [5 rows x 67 columns]

# %%
# Combined DataFrame information
print("Combined DataFrame Info:")
print(combined_df.info())
print(f"\nShape of DataFrame: {combined_df.shape}")
print(f"\nColumns in DataFrame: {combined_df.columns.tolist()}")
# Out:
# Combined DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494100 entries, 0 to 494099
# Data columns (total 67 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   fdc_id_of_sample_food               60280 non-null   float64
#  1   fdc_id_of_acquisition_food          7593 non-null    float64
#  2   source_file                         494100 non-null  object
#  3   text                                494100 non-null  object
#  4   fdc_id                              308372 non-null  object
#  5   acquisition_date                    7619 non-null    object
#  6   market_class                        810 non-null     object
#  7   treatment                           810 non-null     object
#  8   state                               810 non-null     object
#  9   id                                  245380 non-null  float64
#  10  name                                9295 non-null    object
#  11  description                         128263 non-null  object
#  12  seq_num                             21573 non-null   object
#  13  food_attribute_type_id              5625 non-null    object
#  14  value                               5913 non-null    object
#  15  food_nutrient_conversion_factor_id  600 non-null     float64
#  16  protein_value                       312 non-null     float64
#  17  fat_value                           312 non-null     float64
#  18  carbohydrate_value                  312 non-null     float64
#  19  code                                217 non-null     object
#  20  pct_weight                          3066 non-null    object
#  21  is_refuse                           3066 non-null    object
#  22  gram_weight                         19014 non-null   object
#  23  data_points                         158228 non-null  object
#  24  min_year_acqured                    3066 non-null    object
#  25  nutrient_id                         145044 non-null  float64
#  26  amount                              160432 non-null  object
#  27  derivation_id                       144484 non-null  object
#  28  min                                 144484 non-null  object
#  29  max                                 144484 non-null  object
#  30  median                              144484 non-null  object
#  31  footnote                            155449 non-null  object
#  32  min_year_acquired                   155162 non-null  object
#  33  measure_unit_id                     10678 non-null   float64
#  34  portion_description                 15948 non-null   object
#  35  modifier                            10678 non-null   object
#  36  last_updated                        63975 non-null   object
#  37  data_type                           63975 non-null   object
#  38  food_category_id                    63975 non-null   object
#  39  publication_date                    63975 non-null   object
#  40  NDB_number                          287 non-null     float64
#  41  fdc_of_input_food                   5270 non-null    float64
#  42  sr_code                             5270 non-null    object
#  43  sr_description                      5270 non-null    object
#  44  unit                                5270 non-null    object
#  45  portion_code                        5270 non-null    object
#  46  retention_code                      5270 non-null    object
#  47  survey_flag                         5270 non-null    object
#  48  lab_method_id                       112648 non-null  float64
#  49  technique                           280 non-null     object
#  50  brand_description                   6809 non-null    object
#  51  expiration_date                     6809 non-null    object
#  52  label_weight                        6809 non-null    object
#  53  location                            6809 non-null    object
#  54  sales_type                          6809 non-null    object
#  55  sample_lot_nbr                      6809 non-null    object
#  56  sell_by_date                        6809 non-null    object
#  57  store_city                          6809 non-null    object
#  58  store_name                          6809 non-null    object
#  59  store_state                         6809 non-null    object
#  60  upc_code                            6809 non-null    object
#  61  unit_name                           477 non-null     object
#  62  nutrient_nbr                        477 non-null     object
#  63  rank                                477 non-null     object
#  64  food_nutrient_id                    111899 non-null  float64
#  65  adjusted_amount                     111899 non-null  object
#  66  nutrient_name                       111899 non-null  object
# dtypes: float64(13), object(54)
# memory usage: 252.6+ MB
# None
#
# Shape of DataFrame: (494100, 67)
#
# Columns in DataFrame: ['fdc_id_of_sample_food', 'fdc_id_of_acquisition_food', 'source_file', 'text', 'fdc_id', 'acquisition_date', 'market_class', 'treatment', 'state', 'id', 'name', 'description', 'seq_num', 'food_attribute_type_id', 'value', 'food_nutrient_conversion_factor_id', 'protein_value', 'fat_value', 'carbohydrate_value', 'code', 'pct_weight', 'is_refuse', 'gram_weight', 'data_points', 'min_year_acqured', 'nutrient_id', 'amount', 'derivation_id', 'min', 'max', 'median', 'footnote', 'min_year_acquired', 'measure_unit_id', 'portion_description', 'modifier', 'last_updated', 'data_type', 'food_category_id', 'publication_date', 'NDB_number', 'fdc_of_input_food', 'sr_code', 'sr_description', 'unit', 'portion_code', 'retention_code', 'survey_flag', 'lab_method_id', 'technique', 'brand_description', 'expiration_date', 'label_weight', 'location', 'sales_type', 'sample_lot_nbr', 'sell_by_date', 'store_city', 'store_name', 'store_state', 'upc_code', 'unit_name', 'nutrient_nbr', 'rank', 'food_nutrient_id', 'adjusted_amount', 'nutrient_name']

# %%
# Row count from each source file
print("\nRow count from each source file:")
print(combined_df['source_file'].value_counts())
# Out:
# Row count from each source file:
# source_file
# food_nutrient.csv                      144484
# sub_sample_result.csv                  111899
# food_update_log_entry.csv               63975
# food.csv                                63975
# sub_sample_food.csv                     52687
# food_nutrient_conversion_factor.csv     11370
# food_portion.csv                        10678
# acquisition_samples.csv                  7593
# market_acquisition.csv                   6809
# food_attribute.csv                       5625
# input_food.csv                           5270
# sample_food.csv                          3311
# food_component.csv                       3066
# agricultural_samples.csv                  810
# lab_method_nutrient.csv                   560
# nutrient.csv                              477
# food_calorie_conversion_factor.csv        312
# food_protein_conversion_factor.csv        288
# foundation_food.csv                       287
# lab_method.csv                            280
# lab_method_code.csv                       189
# measure_unit.csv                          122
# food_category.csv                          28
# food_attribute_type.csv                     5
# Name: count, dtype: int64

# %%
# Handling missing values (newly revised code)
missing_values = combined_df.isnull().sum()
print(f"Missing values in each column:\n{missing_values}")
# Out:
# Missing values in each column:
# fdc_id_of_sample_food         433820
# fdc_id_of_acquisition_food    486507
# source_file                        0
# text                               0
# fdc_id                        185728
#                                ...
# nutrient_nbr                  493623
# rank                          493623
# food_nutrient_id              382201
# adjusted_amount               382201
# nutrient_name                 382201
# Length: 67, dtype: int64

# %%
# Display the shape and a sample of the combined DataFrame
print(f"Combined DataFrame Shape: {combined_df.shape}")
combined_df.sample(5)
# Out:
# Combined DataFrame Shape: (494100, 67)
#         fdc_id_of_sample_food  fdc_id_of_acquisition_food  \
# 96636                     NaN                         NaN
# 390376                    NaN                         NaN
# 356573              2257056.0                         NaN
# 251676                    NaN                         NaN
# 473467                    NaN                         NaN
#
#                   source_file  \
# 96636       food_nutrient.csv
# 390376  sub_sample_result.csv
# 356573    sub_sample_food.csv
# 251676               food.csv
# 473467  sub_sample_result.csv
#
#                                                      text   fdc_id  \
# 96636   id: 2285173 fdc_id: 335905 nutrient_id: 1009 a...   335905
# 390376  food_nutrient_id: 2226264 adjusted_amount: 0.1...      NaN
# 356573  fdc_id: 2257796 fdc_id_of_sample_food: 2257056...  2257796
# 251676  fdc_id: 324149 data_type: sub_sample_food desc...   324149
# 473467  food_nutrient_id: 27794949 adjusted_amount: 0....      NaN
#
#        acquisition_date market_class treatment state         id  ...  \
# 96636               NaN          NaN       NaN   NaN  2285173.0  ...
# 390376              NaN          NaN       NaN   NaN        NaN  ...
# 356573              NaN          NaN       NaN   NaN        NaN  ...
# 251676              NaN          NaN       NaN   NaN        NaN  ...
# 473467              NaN          NaN       NaN   NaN        NaN  ...
#
#        store_city store_name store_state upc_code unit_name  nutrient_nbr  \
# 96636         NaN        NaN         NaN      NaN       NaN           NaN
# 390376        NaN        NaN         NaN      NaN       NaN           NaN
# 356573        NaN        NaN         NaN      NaN       NaN           NaN
# 251676        NaN        NaN         NaN      NaN       NaN           NaN
# 473467        NaN        NaN         NaN      NaN       NaN           NaN
#
#         rank  food_nutrient_id  adjusted_amount nutrient_name
# 96636    NaN               NaN              NaN           NaN
# 390376   NaN         2226264.0             0.16      Tyrosine
# 356573   NaN               NaN              NaN           NaN
# 251676   NaN               NaN              NaN           NaN
# 473467   NaN        27794949.0             0.28    Methionine
#
# [5 rows x 67 columns]

# %%
# Fill missing values
combined_df.fillna('Unknown', inplace=True)
# Out:
# <ipython-input-37-767f76c711fe>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   combined_df.fillna('Unknown', inplace=True)

# %%
# Sample of the cleaned data
combined_df.sample(5)
# Out:
#        fdc_id_of_sample_food fdc_id_of_acquisition_food  \
# 238825               Unknown                    Unknown
# 277190               Unknown                    Unknown
# 324371               Unknown                    Unknown
# 137074               Unknown                    Unknown
# 360578             2261470.0                    Unknown
#
#                       source_file  \
# 238825  food_update_log_entry.csv
# 277190                   food.csv
# 324371     market_acquisition.csv
# 137074          food_nutrient.csv
# 360578        sub_sample_food.csv
#
#                                                      text   fdc_id  \
# 238825  id: 2516358 description: sunflower seed kernel...  Unknown
# 277190  fdc_id: 2001022 data_type: sub_sample_food des...  2001022
# 324371  fdc_id: 2003633 brand_description: Unknown exp...  2003633
# 137074  id: 24466415 fdc_id: 2001642 nutrient_id: 2009...  2001642
# 360578  fdc_id: 2262048 fdc_id_of_sample_food: 2261470...  2262048
#
#        acquisition_date market_class treatment    state          id  ...  \
# 238825          Unknown      Unknown   Unknown  Unknown   2516358.0  ...
# 277190          Unknown      Unknown   Unknown  Unknown     Unknown  ...
# 324371       2021-03-15      Unknown   Unknown  Unknown     Unknown  ...
# 137074          Unknown      Unknown   Unknown  Unknown  24466415.0  ...
# 360578          Unknown      Unknown   Unknown  Unknown     Unknown  ...
#
#        store_city store_name store_state upc_code unit_name nutrient_nbr  \
# 238825    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 277190    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 324371   (Region)    Unknown        West  Unknown   Unknown      Unknown
# 137074    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 360578    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
#
#            rank food_nutrient_id adjusted_amount nutrient_name
# 238825  Unknown          Unknown         Unknown       Unknown
# 277190  Unknown          Unknown         Unknown       Unknown
# 324371  Unknown          Unknown         Unknown       Unknown
# 137074  Unknown          Unknown         Unknown       Unknown
# 360578  Unknown          Unknown         Unknown       Unknown
#
# [5 rows x 67 columns]

# %% [markdown]
# ##Preprocessing

# %%
# Save the preprocessed data
combined_df.to_csv("preprocessed_nutrition_data.csv", index=False)

# %%
# Load the preprocessed data from the CSV file
preprocessed_df = pd.read_csv("preprocessed_nutrition_data.csv")

# Display DataFrame information and a sample of preprocessed data
print("\nPreprocessed Data Info:")
print(preprocessed_df.info())

print("\nSample of preprocessed data:")
print(preprocessed_df.head())
# Out:
# <ipython-input-40-b71659fba224>:2: DtypeWarning: Columns (0,4,9,23,25,26,27,32,38,48,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   preprocessed_df = pd.read_csv("preprocessed_nutrition_data.csv")
# Preprocessed Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494100 entries, 0 to 494099
# Data columns (total 67 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   fdc_id_of_sample_food               494100 non-null  object
#  1   fdc_id_of_acquisition_food          494100 non-null  object
#  2   source_file                         494100 non-null  object
#  3   text                                494100 non-null  object
#  4   fdc_id                              494100 non-null  object
#  5   acquisition_date                    494100 non-null  object
#  6   market_class                        494100 non-null  object
#  7   treatment                           494100 non-null  object
#  8   state                               494100 non-null  object
#  9   id                                  494100 non-null  object
#  10  name                                494100 non-null  object
#  11  description                         494100 non-null  object
#  12  seq_num                             494100 non-null  object
#  13  food_attribute_type_id              494100 non-null  object
#  14  value                               494100 non-null  object
#  15  food_nutrient_conversion_factor_id  494100 non-null  object
#  16  protein_value                       494100 non-null  object
#  17  fat_value                           494100 non-null  object
#  18  carbohydrate_value                  494100 non-null  object
#  19  code                                494100 non-null  object
#  20  pct_weight                          494100 non-null  object
#  21  is_refuse                           494100 non-null  object
#  22  gram_weight                         494100 non-null  object
#  23  data_points                         494100 non-null  object
#  24  min_year_acqured                    494100 non-null  object
#  25  nutrient_id                         494100 non-null  object
#  26  amount                              494100 non-null  object
#  27  derivation_id                       494100 non-null  object
#  28  min                                 494100 non-null  object
#  29  max                                 494100 non-null  object
#  30  median                              494100 non-null  object
#  31  footnote                            494100 non-null  object
#  32  min_year_acquired                   494100 non-null  object
#  33  measure_unit_id                     494100 non-null  object
#  34  portion_description                 494100 non-null  object
#  35  modifier                            494100 non-null  object
#  36  last_updated                        494100 non-null  object
#  37  data_type                           494100 non-null  object
#  38  food_category_id                    494100 non-null  object
#  39  publication_date                    494100 non-null  object
#  40  NDB_number                          494100 non-null  object
#  41  fdc_of_input_food                   494100 non-null  object
#  42  sr_code                             494100 non-null  object
#  43  sr_description                      494100 non-null  object
#  44  unit                                494100 non-null  object
#  45  portion_code                        494100 non-null  object
#  46  retention_code                      494100 non-null  object
#  47  survey_flag                         494100 non-null  object
#  48  lab_method_id                       494100 non-null  object
#  49  technique                           494100 non-null  object
#  50  brand_description                   494100 non-null  object
#  51  expiration_date                     494100 non-null  object
#  52  label_weight                        494100 non-null  object
#  53  location                            494100 non-null  object
#  54  sales_type                          494100 non-null  object
#  55  sample_lot_nbr                      494100 non-null  object
#  56  sell_by_date                        494100 non-null  object
#  57  store_city                          494100 non-null  object
#  58  store_name                          494100 non-null  object
#  59  store_state                         494100 non-null  object
#  60  upc_code                            494100 non-null  object
#  61  unit_name                           494100 non-null  object
#  62  nutrient_nbr                        494100 non-null  object
#  63  rank                                494100 non-null  object
#  64  food_nutrient_id                    494100 non-null  object
#  65  adjusted_amount                     494100 non-null  object
#  66  nutrient_name                       494100 non-null  object
# dtypes: object(67)
# memory usage: 252.6+ MB
# None
#
# Sample of preprocessed data:
#   fdc_id_of_sample_food fdc_id_of_acquisition_food              source_file  \
# 0              319874.0                   319876.0  acquisition_samples.csv
# 1              319874.0                   319875.0  acquisition_samples.csv
# 2              319879.0                   319881.0  acquisition_samples.csv
# 3              319879.0                   319880.0  acquisition_samples.csv
# 4              319885.0                   319890.0  acquisition_samples.csv
#
#                                                 text   fdc_id  \
# 0  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...  Unknown
# 1  fdc_id_of_sample_food: 319874 fdc_id_of_acquis...  Unknown
# 2  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...  Unknown
# 3  fdc_id_of_sample_food: 319879 fdc_id_of_acquis...  Unknown
# 4  fdc_id_of_sample_food: 319885 fdc_id_of_acquis...  Unknown
#
#   acquisition_date market_class treatment    state       id  ... store_city  \
# 0          Unknown      Unknown   Unknown  Unknown  Unknown  ...    Unknown
# 1          Unknown      Unknown   Unknown  Unknown  Unknown  ...    Unknown
# 2          Unknown      Unknown   Unknown  Unknown  Unknown  ...    Unknown
# 3          Unknown      Unknown   Unknown  Unknown  Unknown  ...    Unknown
# 4          Unknown      Unknown   Unknown  Unknown  Unknown  ...    Unknown
#
#   store_name store_state upc_code unit_name nutrient_nbr     rank  \
# 0    Unknown     Unknown  Unknown   Unknown      Unknown  Unknown
# 1    Unknown     Unknown  Unknown   Unknown      Unknown  Unknown
# 2    Unknown     Unknown  Unknown   Unknown      Unknown  Unknown
# 3    Unknown     Unknown  Unknown   Unknown      Unknown  Unknown
# 4    Unknown     Unknown  Unknown   Unknown      Unknown  Unknown
#
#   food_nutrient_id adjusted_amount nutrient_name
# 0          Unknown         Unknown       Unknown
# 1          Unknown         Unknown       Unknown
# 2          Unknown         Unknown       Unknown
# 3          Unknown         Unknown       Unknown
# 4          Unknown         Unknown       Unknown
#
# [5 rows x 67 columns]

# %% [markdown]
# #Vectorization (Embeddings)

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained model for vectorization
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings using the constructed 'text' column from the combined DataFrame
embeddings = model.encode(combined_df['text'].tolist())

# Save the embeddings
import numpy as np
np.save('nutrition_embeddings.npy', embeddings)

print(f"Embeddings Shape: {embeddings.shape}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Embeddings Shape: (494100, 384)

# %% [markdown]
# ##Create a FAISS index (vector db)

# %%
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings.astype('float32'))

# Save FAISS index
faiss.write_index(index, 'nutrition_faiss.index')

print("FAISS index created and saved. Data processing complete.")
# Out:
# FAISS index created and saved. Data processing complete.

# %%
print(f"Embeddings Shape: {embeddings.shape}")
# Out:
# Embeddings Shape: (494100, 384)

# %% [markdown]
# #Hybrid Search: (OpenAI Text Search & FAISS Vector Search)

# %%
import os
import openai

# Retrieve API key from environment variable or use a placeholder
api_key = os.getenv("OPENAI_API_KEY")

if api_key is None:
    api_key = "YOUR_API_KEY"  # Replace with your actual API key or set the environment variable
    print("Warning: Using placeholder API key. Please set the OPENAI_API_KEY environment variable.")

# Initialize the OpenAI client
client = OpenAI(api_key=api_key)

def search_with_openai(query):
    try:
        response = client.Completion.create( # Use client instead of openai
            model="text-davinci-003",
            prompt=f"Search for: {query}",
            max_tokens=100
        )
        return response['choices'][0]['text']
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example text search query
text_search_result = search_with_openai("apple")

# Check if the search result is valid before printing
if text_search_result:
    print(f"Text Search Result:\n{text_search_result}")
else:
    print("No result returned from the search.")
# Out:
# Warning: Using placeholder API key. Please set the OPENAI_API_KEY environment variable.
# An error occurred: 'OpenAI' object has no attribute 'Completion'
# No result returned from the search.

# %%
# Hybrid search combining text and vector search
def hybrid_search(query):
    # Step 1: Text search using OpenAI
    print("\n--- Text Search with OpenAI ---")
    text_search_result = search_with_openai(query)
    print(f"Text Search Result: {text_search_result}")

    # Step 2: Vector search using FAISS
    print("\n--- Vector Search with FAISS ---")
    query_embedding = model.encode([query])
    D, I = index.search(np.array(query_embedding, dtype=np.float32), k=5)
    print("Vector Search Results:")
    print(combined_df.iloc[I[0]])

# Example hybrid search with the query 'apple'
hybrid_search("apple")
# Out:
# --- Text Search with OpenAI ---
# An error occurred: 'OpenAI' object has no attribute 'Completion'
# Text Search Result: None
#
# --- Vector Search with FAISS ---
# Vector Search Results:
#        fdc_id_of_sample_food fdc_id_of_acquisition_food  \
# 207391               Unknown                    Unknown
# 204799               Unknown                    Unknown
# 207414               Unknown                    Unknown
# 207339               Unknown                    Unknown
# 207349               Unknown                    Unknown
#
#                       source_file  \
# 207391  food_update_log_entry.csv
# 204799  food_update_log_entry.csv
# 207414  food_update_log_entry.csv
# 207339  food_update_log_entry.csv
# 207349  food_update_log_entry.csv
#
#                                                      text   fdc_id  \
# 207391  id: 1752929 description: APPLES, FUJI, WITH SK...  Unknown
# 204799  id: 1105897 description: Apples, fuji, with sk...  Unknown
# 207414  id: 1752952 description: APPLES, FUJI, WITH SK...  Unknown
# 207339  id: 1752877 description: APPLES, FUJI, WITH SK...  Unknown
# 207349  id: 1752887 description: APPLES, FUJI, WITH SK...  Unknown
#
#        acquisition_date market_class treatment    state         id  ...  \
# 207391          Unknown      Unknown   Unknown  Unknown  1752929.0  ...
# 204799          Unknown      Unknown   Unknown  Unknown  1105897.0  ...
# 207414          Unknown      Unknown   Unknown  Unknown  1752952.0  ...
# 207339          Unknown      Unknown   Unknown  Unknown  1752877.0  ...
# 207349          Unknown      Unknown   Unknown  Unknown  1752887.0  ...
#
#        store_city store_name store_state upc_code unit_name nutrient_nbr  \
# 207391    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 204799    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 207414    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 207339    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
# 207349    Unknown    Unknown     Unknown  Unknown   Unknown      Unknown
#
#            rank food_nutrient_id adjusted_amount nutrient_name
# 207391  Unknown          Unknown         Unknown       Unknown
# 204799  Unknown          Unknown         Unknown       Unknown
# 207414  Unknown          Unknown         Unknown       Unknown
# 207339  Unknown          Unknown         Unknown       Unknown
# 207349  Unknown          Unknown         Unknown       Unknown
#
# [5 rows x 67 columns]

# %% [markdown]
# #RAG Pipeline (Prompt Building and Response Generation)

# %% [markdown]
# ## FAISS-based Retrieval and OpenAI Completion

# %%
import faiss
from sentence_transformers import SentenceTransformer
import openai
import pandas as pd

# Load OpenAI API Key securely from environment variable
openai.api_key = os.getenv('OPENAI_API_KEY')

# Class to handle RAG pipeline
class NutritionRAG:
    def __init__(self, df_nutrients):
        self.df_nutrients = df_nutrients
        self.model = SentenceTransformer('all-MiniLM-L6-v2')
        self.index = self.build_index()  # Build FAISS index using embeddings

    def build_index(self):
        # Ensure 'description' column exists
        texts = self.df_nutrients['description'].tolist()  # Ensure this column exists
        embeddings = self.model.encode(texts)
        index = faiss.IndexFlatL2(embeddings.shape[1])
        index.add(embeddings.astype('float32'))
        return index

    def retrieve(self, query, k=5):
        # Generate the query embedding
        query_vector = self.model.encode([query])
        # Perform the FAISS vector search
        _, indices = self.index.search(query_vector.astype('float32'), k)
        # Retrieve and return the top k documents
        return self.df_nutrients.iloc[indices[0]]

    def generate_response(self, query):
        # Retrieve relevant documents using the vector search
        relevant_docs = self.retrieve(query)
        # Build the context using the 'description' field
        context = "\n".join(relevant_docs['description'].tolist())

        # Construct the prompt for the GPT model
        prompt = f"""Based on the following nutritional information:\n\n{context}\n\nAnswer the following question: {query}\nProvide a concise and informative answer based on the given nutritional information."""

        # Query OpenAI API to generate the response
    def llm(prompt, model='gpt-4o'):
        response = client.chat.completions.create(
        model=model,
        messages=[
                {"role": "system", "content": "You are a helpful nutrition assistant."},
                {"role": "user", "content": prompt}
            ]
        )

        return response.choices[0].message.content

# %%
# Example usage
if __name__ == "__main__":
    # Load the preprocessed data from CSV
    df_food = pd.read_csv("preprocessed_nutrition_data.csv")

    # Initialize the RAG system with the data
    rag = NutritionRAG(df_food)

    # Example query
    query = "How many different types of milk are there?"
    response = rag.generate_response(query)
    print(f"Query: {query}")
    print(f"Response: {response}")
# Out:
# <ipython-input-58-a5f9cee7736b>:4: DtypeWarning: Columns (0,4,9,23,25,26,27,32,38,48,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food = pd.read_csv("preprocessed_nutrition_data.csv")
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Query: How many different types of milk are there?
# Response: None

# %% [markdown]
# # Evaluation
#
# Types of Evaluations on your Retrieval-Augmented Generation (RAG) system:
#
# - Ground Truth Evaluation: Compares the generated output with a known set of correct answers (ground truth).
# - Text-Based Evaluation: Evaluates the accuracy or relevance of the text returned by the OpenAI model (text-based retrieval).
# - Vector-Based Evaluation: Evaluates the quality of document retrieval based on vector similarity.
# - Offline RAG Evaluation: Involves comparing cosine similarity between query embeddings and document embeddings and potentially using a Large Language Model (LLM) as a judge.

# %% [markdown]
# ##Eval 1: Ground Truth Evaluation

# %%
# Ground Truth Evaluation
import csv

def evaluate_retrieval(rag, queries, k=5):
    model = rag.model
    total_similarity = 0
    results = []

    for query in queries:
        retrieved = rag.retrieve(query, k)
        query_vector = model.encode([query])[0]
        retrieved_vectors = model.encode(retrieved['text'].tolist())
        similarities = cosine_similarity([query_vector], retrieved_vectors)[0]
        total_similarity += np.mean(similarities)
        results.append({"query": query, "similarity": np.mean(similarities)})

    avg_similarity = total_similarity / len(queries)

    # Save results to a CSV file
    with open('ground_truth_eval_results.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["query", "similarity"])
        writer.writeheader()
        writer.writerows(results)

    return avg_similarity

test_queries = [
    "What's the protein content in chicken breast?",
    "How many calories are in an avocado?",
    "What's the nutritional value of spinach?",
    "Compare the fat content of whole milk and skim milk.",
    "What are the macronutrients in a banana?"
]

retrieval_score = evaluate_retrieval(rag, test_queries)
print(f"Average retrieval similarity score: {retrieval_score}")


print("\nEvaluating RAG responses:")
for query in test_queries:
    response = rag.generate_response(query)
    print(f"\nQuery: {query}")
    print(f"Response: {response}")
    rating = input("Rate this response (1-5): ")
    print("\n")
# Out:
# Average retrieval similarity score: 0.42214701771736146
#
# Evaluating RAG responses:
#
# Query: What's the protein content in chicken breast?
# Response: None
# Rate this response (1-5): 1
#
#
#
# Query: How many calories are in an avocado?
# Response: None
# Rate this response (1-5): 1
#
#
#
# Query: What's the nutritional value of spinach?
# Response: None
# Rate this response (1-5): 1
#
#
#
# Query: Compare the fat content of whole milk and skim milk.
# Response: None
# Rate this response (1-5): 1
#
#
#
# Query: What are the macronutrients in a banana?
# Response: None
# Rate this response (1-5): 1

# %% [markdown]
# ## Eval 2: Text-Based Evaluation

# %%
# Text-Based Evaluation
import csv
from sklearn.metrics import jaccard_score
import re

def clean_text(text):
    return re.sub(r'\W+', ' ', text).lower()

def text_eval(rag_system, queries):
    """
    Evaluate the textual relevance of RAG responses based on retrieved context.

    rag_system: the RAG pipeline instance
    queries: list of queries to test
    """
    results = []
    for query in queries:
        response = rag_system.generate_response(query)
        retrieved_docs = rag_system.retrieve(query)
        context = "\n".join(retrieved_docs['Description'].tolist())
        similarity = jaccard_score(clean_text(response), clean_text(context))
        results.append({
            "query": query,
            "response": response,
            "context": context,
            "similarity": similarity
        })
        print(f"Query: {query}\nResponse: {response}\nContext: {context}")
        print(f"Jaccard Similarity: {similarity}")
        print("-" * 50)

    # Calculate average similarity
    avg_similarity = sum([res["similarity"] for res in results]) / len(results)
    print(f"Average Jaccard Similarity: {avg_similarity:.2f}")

    # Save results to a CSV file
    with open('text_based_eval_results.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["query", "response", "context", "similarity"])
        writer.writeheader()
        writer.writerows(results)

    return avg_similarity

# %% [markdown]
# ## Eval 3: Vector-Based Evaluation

# %%
# Vector-Based Evaluation
import csv
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def vector_eval(rag_system, queries, k=5):
    """
    Evaluate the vector similarity between query and retrieved documents using cosine similarity.

    rag_system: the RAG pipeline instance
    queries: list of queries to test
    k: number of top documents to retrieve
    """
    total_similarity = 0
    model = rag_system.model  # SentenceTransformer model
    results = []

    for query in queries:
        query_embedding = model.encode([query])
        retrieved_docs = rag_system.retrieve(query, k=k)
        retrieved_embeddings = model.encode(retrieved_docs['Description'].tolist())

        similarity = cosine_similarity(query_embedding, retrieved_embeddings).mean()
        total_similarity += similarity

        # Save each result
        results.append({
            "query": query,
            "similarity": similarity
        })

        print(f"Query: {query}")
        print(f"Average Cosine Similarity for retrieved docs: {similarity:.2f}")
        print("-" * 50)

    avg_similarity = total_similarity / len(queries)
    print(f"Average Cosine Similarity across all queries: {avg_similarity:.2f}")

    # Save results to a CSV file
    with open('vector_based_eval_results.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["query", "similarity"])
        writer.writeheader()
        writer.writerows(results)

    return avg_similarity

# %% [markdown]
# ##Eval 4: Offline RAG Evaluation (Using Cosine Similarity & LLM as a Judge)

# %%
import csv
import os
import numpy as np
import openai

# Load OpenAI API Key securely from environment variable
openai.api_key = os.getenv('OPENAI_API_KEY')

# Load the processed data from the CSV file
preprocessed_data = pd.read_csv('preprocessed_nutrition_data.csv')

# Cosine Similarity and LLM-based Evaluation
def offline_rag_eval(nutrition_rag, queries, ground_truth, model='gpt-4o'):
    """
    Evaluate RAG-generated responses using cosine similarity and LLM as a judge.

    nutrition_rag: the RAG pipeline instance
    queries: list of queries to test
    ground_truth: list of correct answers (from dataset)
    model: LLM model to use for evaluation (default is 'gpt-4o')
    """
    total_cosine_similarity = 0
    evaluations = []

    for i, query in enumerate(queries):
        response = nutrition_rag.generate_response(query)  # Call the instance method
        original_text = ground_truth[i]

        # Calculate Cosine Similarity between response and original text
        v_response = nutrition_rag.model.encode(response)  # Use the nutrition_rag instance
        v_original = nutrition_rag.model.encode(original_text)  # Use the nutrition_rag instance
        cosine_sim = np.dot(v_response, v_original) / (np.linalg.norm(v_response) * np.linalg.norm(v_original))

        # LLM-based evaluation using OpenAI API
        prompt = f"""
        You're evaluating the relevance of a generated response.
        Original Text: "{original_text}"
        Generated Response: "{response}"
        Please evaluate the relevance between the two.
        """
        llm_response = client.Completion.create(model=model, prompt=prompt, max_tokens=100)
        eval_result = llm_response['choices'][0]['text'].strip()

        evaluations.append({
            'query': query,
            'response': response,
            'original_text': original_text,
            'cosine_similarity': cosine_sim,
            'LLM_evaluation': eval_result
        })
        total_cosine_similarity += cosine_sim

        # Display the results for the current query
        print(f"Query: {query}")
        print(f"Cosine Similarity: {cosine_sim:.2f}")
        print(f"LLM Evaluation: {eval_result}")
        print("-" * 50)

    avg_cosine_similarity = total_cosine_similarity / len(queries)

    # Display the average cosine similarity for the entire evaluation
    print(f"Average Cosine Similarity: {avg_cosine_similarity:.2f}")

    # Save results to a CSV file
    with open('offline_rag_eval_results.csv', mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["query", "response", "original_text", "cosine_similarity", "LLM_evaluation"])
        writer.writeheader()
        writer.writerows(evaluations)

    return evaluations, avg_cosine_similarity

# Call the evaluation function
evaluations, avg_cosine = offline_rag_eval(nutrition_rag, queries, ground_truth)

# %% [markdown]
# # Monitoring

# %% [markdown]
# ## Interactive Monitoring

# %%
import csv

class MonitoredRAG:
    def __init__(self, rag_system):
        self.rag_system = rag_system  # Your RAG system with FAISS and OpenAI
        self.query_count = 0
        self.response_times = []
        self.user_ratings = []

    def generate_response(self, query):
        start_time = datetime.now()

        # Generate response using FAISS and OpenAI
        response = self.rag_system.generate_response(query)  # Assumes rag_system has 'generate_response'

        end_time = datetime.now()
        # Track response time
        response_time = (end_time - start_time).total_seconds()

        # Update counters
        self.query_count += 1
        self.response_times.append(response_time)

        # Save the response time to a CSV file
        with open('monitoring_response_times.csv', mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([query, response_time])

        return response

    def add_rating(self, rating):
        self.user_ratings.append(rating)

        # Save the user rating to a CSV file
        with open('monitoring_user_ratings.csv', mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([self.query_count, rating])

# Initialize the monitoring system with your RAG system (FAISS + OpenAI)
monitored_rag = MonitoredRAG(rag_system)

# User Input Interface
query_input = widgets.Text(description="Query:", style={'description_width': 'initial'})
submit_button = widgets.Button(description="Submit")
rating_slider = widgets.IntSlider(value=3, min=1, max=5, step=1, description="Rate (1-5):")
output = widgets.Output()

# Handle submission
def on_submit_button_clicked(b):
    with output:
        clear_output()
        print(f"Query: {query_input.value}")
        response = monitored_rag.generate_response(query_input.value)
        print(f"Response: {response}")

# Handle rating updates
def on_rating_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        monitored_rag.add_rating(change['new'])

submit_button.on_click(on_submit_button_clicked)
rating_slider.observe(on_rating_change)

# Display the monitoring interface
display(widgets.VBox([query_input, submit_button, rating_slider, output]))

# %% [markdown]
# ## Real Time Dashboard

# %%
dashboard_output = widgets.Output()

def update_dashboard():
    with dashboard_output:
        clear_output()
        print(f"Total Queries: {monitored_rag.query_count}")

        # Save query count and response times to CSV
        with open('monitoring_dashboard.csv', mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([monitored_rag.query_count, monitored_rag.response_times])

        if monitored_rag.response_times:
            fig_times = px.line(x=range(len(monitored_rag.response_times)), y=monitored_rag.response_times, title="Response Times")
            fig_times.show()
        if monitored_rag.user_ratings:
            avg_rating = sum(monitored_rag.user_ratings) / len(monitored_rag.user_ratings)
            fig_ratings = px.histogram(monitored_rag.user_ratings, title="User Ratings Distribution")
            print(f"Average User Rating: {avg_rating:.2f}")
            fig_ratings.show()

# Create dashboard update button
update_dashboard_button = widgets.Button(description="Update Dashboard")
update_dashboard_button.on_click(update_dashboard)

# Display the dashboard interface
display(widgets.VBox([update_dashboard_button, dashboard_output]))

# %% [markdown]
# ##Download files

# %%
from google.colab import files

# List of all files to download (with /content/ path added)
file_paths = [
    '/content/csv_file_columns.csv',
    '/content/preprocessed_nutrition_data.csv',
    '/content/nutrition_embeddings.npy',
    '/content/nutrition_faiss.index',
    '/content/ground_truth_eval_results.csv',
    '/content/text_based_eval_results.csv',
    '/content/vector_based_eval_results.csv',
    '/content/offline_rag_eval_results.csv',
    '/content/monitoring_response_times.csv',
    '/content/monitoring_user_ratings.csv',
    '/content/monitoring_dashboard.csv'
]

# Loop through the list and download each file
for file_path in file_paths:
    try:
        # Download each file one by one
        files.download(file_path)
        print(f"Downloaded: {file_path}")
    except Exception as e:
        print(f"Failed to download {file_path}: {e}")
